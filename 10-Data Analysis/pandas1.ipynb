# %% [markdown]
# ### Importing Pandas
# Standard setup for data analysis.

# %%
import pandas as pd

# %% [markdown]
# ### Loading Datasets
# Reading a CSV file containing product information.

# %%
df=pd.read_csv('product.csv')
df.head()
# Out:
#    S.No BrandName Product ID              Product Name  \
# 0     1      4711      FR001         Cologne Fragrance
# 1     2      109f       DRW1  DRW1 - Westernwear-Women
# 2     3      109f       DRW2  DRW2 - Westernwear-Women
# 3     4      109f       DRW3  DRW3 - Westernwear-Women
# 4     5      109f       DRW4  DRW4 - Westernwear-Women
#
#                                      Brand Desc  \
# 0                     ekw eau de cologne 400 ml
# 1           womens v- neck short dress - yellow
# 2           womens round neck solid top - black
# 3    womens round neck stripe shift dress - red
# 4  womens round neck solid high low top - black
#
#                          Product Size Currancy   MRP  SellPrice Discount  \
# 0                               Small      Rs.  3900       3120  20% off
# 1  Size:Medium,Small,X-Large,XX-Large      Rs.  1899        569  70% off
# 2     Size:Large,Medium,Small,X-Large      Rs.  1499        599  60% off
# ...

# %% [markdown]
# ### Inspecting Sample Data
# Viewing the last few rows of the dataset.

# %%
df.tail()
# Out:
#       S.No       BrandName        Product ID  \
# 4561  4562  crimsoune club   CRIMSOUNE CLUB6
# 4562  4563  crimsoune club   CRIMSOUNE CLUB7
# 4563  4564  crimsoune club   CRIMSOUNE CLUB8
# 4564  4565  crimsoune club   CRIMSOUNE CLUB9
# 4565  4566  crimsoune club  CRIMSOUNE CLUB10
#
#                               Product Name  \
# 4561   CRIMSOUNE CLUB6 - Westernwear-Women
# 4562   CRIMSOUNE CLUB7 - Westernwear-Women
# 4563   CRIMSOUNE CLUB8 - Westernwear-Women
# 4564   CRIMSOUNE CLUB9 - Westernwear-Women
# 4565  CRIMSOUNE CLUB10 - Westernwear-Women
#
#                                              Brand Desc  \
# 4561  solid hood poly cotton womens sweatshirt - yellow
# 4562  striped v-neck cotton womens casual shirt - white
# 4563                  womens slim fit solid shirt - red
# 4564      printed lyocell round neck womens top - green
# 4565                 womens grey solid jumpsuit - denim
#
#                                            Product Size Currancy   MRP  \
# ...

# %% [markdown]
# ### Summary Statistics
# Gaining a statistical overview of numerical columns.

# %%
df.describe()
# Out:
#               S.No     SellPrice
# count  4566.000000   4566.000000
# mean   2283.500000   2005.222733
# std    1318.234994   2259.614915
# min       1.000000     89.000000
# 25%    1142.250000    749.000000
# 50%    2283.500000   1379.000000
# 75%    3424.750000   2299.000000
# max    4566.000000  25995.000000

# %% [markdown]
# ### Data Type Inspection
# Checking the schema to identify categorical and numerical fields.

# %%
df.dtypes
# Out:
# S.No            int64
# BrandName         str
# Product ID        str
# Product Name      str
# Brand Desc        str
# Product Size      str
# Currancy          str
# MRP               str
# SellPrice       int64
# Discount          str
# Category          str
# dtype: object

# %% [markdown]
# ### Identifying Missing Values
# Scanning the entire dataset for null or empty entries.

# %%
##Handling miisng value 
df.isnull()
# Out:
#        S.No  BrandName  Product ID  Product Name  Brand Desc  Product Size  \
# 0     False      False       False         False       False         False
# 1     False      False       False         False       False         False
# 2     False      False       False         False       False         False
# 3     False      False       False         False       False         False
# 4     False      False       False         False       False         False
# ...     ...        ...         ...           ...         ...           ...
# 4561  False      False       False         False       False         False
# 4562  False      False       False         False       False         False
# 4563  False      False       False         False       False         False
# 4564  False      False       False         False       False         False
# 4565  False      False       False         False       False         False
#
#       Currancy    MRP  SellPrice  Discount  Category
# ...

# %% [markdown]
# ### Quantification of Missing Data
# Counting the number of null entries per column.

# %%
df.isnull().sum()
# Out:
# S.No             0
# BrandName        0
# Product ID       0
# Product Name     0
# Brand Desc       0
# Product Size     0
# Currancy         0
# MRP             13
# SellPrice        0
# Discount         0
# Category         0
# dtype: int64

# %% [markdown]
# ### Post-Cleaning Type Verification

# %%
df.dtypes
# Out:
# S.No              int64
# BrandName           str
# Product ID          str
# Product Name        str
# Brand Desc          str
# Product Size        str
# Currancy            str
# MRP             float64
# SellPrice         int64
# Discount            str
# Category            str
# MRP_fillNA      float64
# dtype: object

# %%
## Renaming the column 

df.rename(columns={'MRP':'OG-PRICE'})
# Out:
#       S.No       BrandName        Product ID  \
# 0        1            4711             FR001
# 1        2            109f              DRW1
# 2        3            109f              DRW2
# 3        4            109f              DRW3
# 4        5            109f              DRW4
# ...    ...             ...               ...
# 4561  4562  crimsoune club   CRIMSOUNE CLUB6
# 4562  4563  crimsoune club   CRIMSOUNE CLUB7
# 4563  4564  crimsoune club   CRIMSOUNE CLUB8
# 4564  4565  crimsoune club   CRIMSOUNE CLUB9
# 4565  4566  crimsoune club  CRIMSOUNE CLUB10
#
#                               Product Name  \
# 0                        Cologne Fragrance
# 1                 DRW1 - Westernwear-Women
# 2                 DRW2 - Westernwear-Women
# 3                 DRW3 - Westernwear-Women
# 4                 DRW4 - Westernwear-Women
# ...                                    ...
# 4561   CRIMSOUNE CLUB6 - Westernwear-Women
# 4562   CRIMSOUNE CLUB7 - Westernwear-Women
# ...

# %%
##Changeing the datatype

df['MRP']=df['MRP'].fillna(df['MRP'].mean()).astype(int)

# %%
df.dtypes
# Out:
# S.No              int64
# BrandName           str
# Product ID          str
# Product Name        str
# Brand Desc          str
# Product Size        str
# Currancy            str
# MRP               int64
# SellPrice         int64
# Discount            str
# Category            str
# MRP_fillNA      float64
# dtype: object

# %%
df.head()
# Out:
#    S.No BrandName Product ID              Product Name  \
# 0     1      4711      FR001         Cologne Fragrance
# 1     2      109f       DRW1  DRW1 - Westernwear-Women
# 2     3      109f       DRW2  DRW2 - Westernwear-Women
# 3     4      109f       DRW3  DRW3 - Westernwear-Women
# 4     5      109f       DRW4  DRW4 - Westernwear-Women
#
#                                      Brand Desc  \
# 0                     ekw eau de cologne 400 ml
# 1           womens v- neck short dress - yellow
# 2           womens round neck solid top - black
# 3    womens round neck stripe shift dress - red
# 4  womens round neck solid high low top - black
#
#                          Product Size Currancy   MRP  SellPrice Discount  \
# 0                               Small      Rs.  3900       3120  20% off
# 1  Size:Medium,Small,X-Large,XX-Large      Rs.  1899        569  70% off
# 2     Size:Large,Medium,Small,X-Large      Rs.  1499        599  60% off
# ...

# %%
 ## Data Aggregation and Grouping 
grouped_mean=df.groupby('Product Name')['MRP'].mean()
print(grouped_mean)
# Out:
# Product Name
# AARKE1 - Westernwear-Women    3190.0
# AARKE10 - Indianwear-Women    6160.0
# AARKE11 - Indianwear-Women    2970.0
# AARKE12 - Indianwear-Women    3850.0
# AARKE13 - Indianwear-Women    6490.0
#                                ...
# DRW96 - Westernwear-Women     2299.0
# DRW97 - Westernwear-Women     1499.0
# DRW98 - Westernwear-Women     1999.0
# DRW99 - Westernwear-Women     1299.0
# FW1 - Fragrance-Women         6050.0
# Name: MRP, Length: 4566, dtype: float64

# %%
group_sum=df.groupby(['Product Size','SellPrice'])["MRP"].sum()
print(group_sum)
# Out:
# Product Size             SellPrice
# Nan                      89           2682
#                          99           2178
#                          119          2388
#                          124           496
#                          125             0
#                                       ...
# Size:XX-Large            3399            8
# Size:XX-Large,XXX-Large  524          1049
# Size:XXX-Large           909          2598
#                          1049         1499
# Small                    3120         3900
# Name: MRP, Length: 2379, dtype: int64

# %%
##Merging and joining dataframes
#create sample df

df1=pd.DataFrame({'key':['A','B','C'],'Value':[1,2,3]})
df2=pd.DataFrame({'key':['A','B','D'],'Value':[4,5,6]})

# %%
df1
# Out:
#   key  Value
# 0   A      1
# 1   B      2
# 2   C      3

# %%
df2
# Out:
#   key  Value
# 0   A      4
# 1   B      5
# 2   D      6

# %%
##Merge DF on the KEY columns

pd.merge(df1,df2,on="key",how="inner")
# Out:
#   key  Value_x  Value_y
# 0   A        1        4
# 1   B        2        5

# %%
pd.merge(df1,df2,on="key",how="outer")
# Out:
#   key  Value_x  Value_y
# 0   A      1.0      4.0
# 1   B      2.0      5.0
# 2   C      3.0      NaN
# 3   D      NaN      6.0

# %%
pd.merge(df1,df2,on="key",how="left")
# Out:
#   key  Value_x  Value_y
# 0   A        1      4.0
# 1   B        2      5.0
# 2   C        3      NaN

# %%
pd.merge(df1,df2,on="key",how="right")
# Out:
#   key  Value_x  Value_y
# 0   A      1.0        4
# 1   B      2.0        5
# 2   D      NaN        6
