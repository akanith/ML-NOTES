# %% [markdown]
# ### Introduction to Classes and Objects
# Defining a class and instantiating objects.

# %%
### A class is a blue print for creating objects , Attributes,Methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %% [markdown]
# ### Dynamic Attribute Assignment
# Adding attributes to objects after creation.

# %%
audi.windows=4
print(audi.windows)
# Out:
# 4

# %% [markdown]
# ### Instance Variables and Constructors
# Using __init__ to initialize object state.

# %%
### instance Variable and Methods

class Dog:
    ##Constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

## Create Object

dog1=Dog("Tom",3)
print(dog1)
print(dog1.name)
print(dog1.age)

dog2=Dog("Tomy",1)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# ...
# Tom
# 3
# ...
# Tomy
# 1

# %% [markdown]
# ### Defining and Calling Instance Methods
# Adding behaviors to classes.

# %%
## Define a class with instance methods

class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def bark(self):
        print(f"{self.name} say woof")

dog1=Dog("Buddy",3)
dog1.bark()

dog2=Dog("Tom",3)
dog2.bark()
# Out:
# Buddy say woof
# Tom say woof

# %% [markdown]
# ### Modeling a Bank Account
# A complex example with state (Balance) and behaviors (deposit, withdraw).

# %%
## Modeling a Bank Account 
class BankAccount :
    def __init__(self,Owner,Balance=0):
        self.Owner=Owner
        self.Balance=Balance

    def deposit(self,amount):
        self.Balance+=amount
        print(f"{amount} is deposited.\n New Balance is {self.Balance}")

    def withdraw (self,amount):
        self.Balance-=amount
        print(f"{amount} is withdrawn.\n new Balance is{self.Balance}")

    def get_balance(self):
        return self.Balance


account=BankAccount("Anith",10000)
print(account.Balance)
# Out:
# 10000

# %% [markdown]
# ### Calling Methods to Update State

# %%
## Call instance methode

account.deposit(5000)
# Out:
# 5000 is deposited.
#  New Balance is 15000

# %% [markdown]
# ### Retrieving Transformed State

# %%
print(account.get_balance())
# Out:
# 15000
